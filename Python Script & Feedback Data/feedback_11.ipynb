# %%
import pandas as pd

# %%
res_sheet = pd.read_csv(r"C:\Users\abc\Desktop\feedback\feedback.csv")

# %%
res_sheet
# Out:
#             Timestamp                       Email Address  \
# 0   1/1/2024 14:02:23            pradeepkrj0516@gmail.com
# 1   1/1/2024 14:02:31             htsrinivasa86@gmail.com
# 2   1/1/2024 14:08:43         kalyansingh.patil@gmail.com
# 3   1/1/2024 14:13:02     saradha_a@ethirajcollege.edu.in
# 4   1/1/2024 14:13:37              shijjishukla@gmail.com
# 5   1/1/2024 14:14:00                kashavdev2@gmail.com
# 6   1/1/2024 14:14:13                   sangb30@gmail.com
# 7   1/1/2024 14:14:15              sonika.hpurc@gmail.com
# 8   1/1/2024 14:15:20              sharmasonael@gmail.com
# 9   1/1/2024 14:15:47         anuradhagogoi2019@gmail.com
# 10  1/1/2024 14:15:59                ved.arun27@gmail.com
# 11  1/1/2024 14:16:17  hemamalini_c@ethirajcollege.edu.in
# 12  1/1/2024 14:16:23                kunturkars@gmail.com
# 13  1/1/2024 14:16:58             sanlokhande87@gmail.com
# 14  1/1/2024 14:17:26               rsp.seondha@gmail.com
# ...

# %%
communication_to_match = "Communication Skill"
communication_chunk = res_sheet.filter(like=communication_to_match)

# %%
communication_chunk
# Out:
#    Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                  5 (Very effective)
# 1                                  5 (Very effective)
# 2                                       4 (Effective)
# 3                                  5 (Very effective)
# 4                                  5 (Very effective)
# 5                                  5 (Very effective)
# 6                                  5 (Very effective)
# 7                                    3 (Satisfactory)
# 8                                  5 (Very effective)
# 9                                  5 (Very effective)
# 10                                      4 (Effective)
# 11                                      4 (Effective)
# 12                                 5 (Very effective)
# 13                                 5 (Very effective)
# 14                                 5 (Very effective)
# 15                                 5 (Very effective)
# ...

# %%
a = communication_chunk.replace("5 (Very effective)",5)
b = a.replace("4 (Effective)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)
communication = d
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_9048\1522645232.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d = c.replace("2 (Ineffective)",2)

# %%
communication
# Out:
#     Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                                   5
# 1                                                   5
# 2                                                   4
# 3                                                   5
# 4                                                   5
# 5                                                   5
# 6                                                   5
# 7                                                   3
# 8                                                   5
# 9                                                   5
# 10                                                  4
# 11                                                  4
# 12                                                  5
# 13                                                  5
# 14                                                  5
# 15                                                  5
# ...

# %%
communication
# Out:
#     Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                                   5
# 1                                                   5
# 2                                                   4
# 3                                                   5
# 4                                                   5
# 5                                                   5
# 6                                                   5
# 7                                                   3
# 8                                                   5
# 9                                                   5
# 10                                                  4
# 11                                                  4
# 12                                                  5
# 13                                                  5
# 14                                                  5
# 15                                                  5
# ...

# %%
communication_rank = communication.transpose()

# %%
communication_rank
# Out:
#                                                     0   1   2   3   4   5   \
# Communication Skill [Alok Chakrawal (Implementa...   5   5   4   5   5   5
# Communication Skill [Dr. Sandeep Atre (Teacher ...   5   5   4   5   5   5
# Communication Skill [Dr. Ragini Khubalkar (Inte...   5   5   5   5   5   5
# Communication Skill [Dr. Vaniki Joshi (Developi...   4   5   5   5   5   5
# Communication Skill [Dr. Mohit Lohane (Digital ...   5   5   3   5   5   5
# Communication Skill [Dr. Vivek Sharma (Teaching...   4   5   2   5   5   5
# Communication Skill [Dr. N.K.Totla (Qualitative...   5   5   3   5   5   5
# Communication Skill [Dr. Shine David (Explorato...   5   5   5   5   5   5
# Communication Skill [Dr. Vivek Kushwah (Assesme...   5   5   5   5   5   5
# Communication Skill [Dr. Prateek Maheshwari (In...   4   5   4   5   5   5
# Communication Skill [Dr Pradeep MishraOER)]          4   5   5   5   5   5
# ...

# %%
communication_rank.sum(axis=1)
# Out:
# Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]                                                                          214
# Communication Skill [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]                                                     215
# Communication Skill [Dr. Ragini Khubalkar (Intellectual Property Rights)]                                                                                      212
# Communication Skill [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]                                                      216
# Communication Skill [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]                                                               213
# Communication Skill [Dr. Vivek Sharma (Teaching research in NEP 2020)]                                                                                         210
# ...
