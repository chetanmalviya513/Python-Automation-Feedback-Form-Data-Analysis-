# %%
import pandas as pd

# %%
res_sheet = pd.read_csv(r"C:\Users\abc\Desktop\feedback\feedback.csv")

# %%
print(res_sheet)
# Out:
#             Timestamp                       Email Address  \
# 0   1/1/2024 14:02:23            pradeepkrj0516@gmail.com
# 1   1/1/2024 14:02:31             htsrinivasa86@gmail.com
# 2   1/1/2024 14:08:43         kalyansingh.patil@gmail.com
# 3   1/1/2024 14:13:02     saradha_a@ethirajcollege.edu.in
# 4   1/1/2024 14:13:37              shijjishukla@gmail.com
# 5   1/1/2024 14:14:00                kashavdev2@gmail.com
# 6   1/1/2024 14:14:13                   sangb30@gmail.com
# 7   1/1/2024 14:14:15              sonika.hpurc@gmail.com
# 8   1/1/2024 14:15:20              sharmasonael@gmail.com
# 9   1/1/2024 14:15:47         anuradhagogoi2019@gmail.com
# 10  1/1/2024 14:15:59                ved.arun27@gmail.com
# 11  1/1/2024 14:16:17  hemamalini_c@ethirajcollege.edu.in
# 12  1/1/2024 14:16:23                kunturkars@gmail.com
# 13  1/1/2024 14:16:58             sanlokhande87@gmail.com
# 14  1/1/2024 14:17:26               rsp.seondha@gmail.com
# ...

# %%
res_sheet
# Out:
#             Timestamp                       Email Address  \
# 0   1/1/2024 14:02:23            pradeepkrj0516@gmail.com
# 1   1/1/2024 14:02:31             htsrinivasa86@gmail.com
# 2   1/1/2024 14:08:43         kalyansingh.patil@gmail.com
# 3   1/1/2024 14:13:02     saradha_a@ethirajcollege.edu.in
# 4   1/1/2024 14:13:37              shijjishukla@gmail.com
# 5   1/1/2024 14:14:00                kashavdev2@gmail.com
# 6   1/1/2024 14:14:13                   sangb30@gmail.com
# 7   1/1/2024 14:14:15              sonika.hpurc@gmail.com
# 8   1/1/2024 14:15:20              sharmasonael@gmail.com
# 9   1/1/2024 14:15:47         anuradhagogoi2019@gmail.com
# 10  1/1/2024 14:15:59                ved.arun27@gmail.com
# 11  1/1/2024 14:16:17  hemamalini_c@ethirajcollege.edu.in
# 12  1/1/2024 14:16:23                kunturkars@gmail.com
# 13  1/1/2024 14:16:58             sanlokhande87@gmail.com
# 14  1/1/2024 14:17:26               rsp.seondha@gmail.com
# ...

# %% [markdown]
# res_sheet data filter function uses then chunk of response data

# %% [markdown]
# 1. Communication Skill 2. Quality of lecture 3. Competency in Subject 4. Usefulness of Topic/s and other 13 Question chunk

# %%
# First Communication Skill data chunk 

communication_to_match = "Communication Skill"
chunk_communication = res_sheet.filter(like=communication_to_match)


#chunk_communication.to_csv("communication_chunk.csv",index=False)

# %%
chunk_communication
# Out:
#    Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                  5 (Very effective)
# 1                                  5 (Very effective)
# 2                                       4 (Effective)
# 3                                  5 (Very effective)
# 4                                  5 (Very effective)
# 5                                  5 (Very effective)
# 6                                  5 (Very effective)
# 7                                    3 (Satisfactory)
# 8                                  5 (Very effective)
# 9                                  5 (Very effective)
# 10                                      4 (Effective)
# 11                                      4 (Effective)
# 12                                 5 (Very effective)
# 13                                 5 (Very effective)
# 14                                 5 (Very effective)
# 15                                 5 (Very effective)
# ...

# %%
# second Quality of lecture data chunk

quality_to_match = "Quality of lecture"
chunk_quality = res_sheet.filter(like=quality_to_match)

# %%
chunk_quality
# Out:
#    Quality of lecture [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                            4 (Good)
# 1                                       5 (Very Good)
# 2                                       5 (Very Good)
# 3                                       5 (Very Good)
# 4                                       5 (Very Good)
# 5                                       5 (Very Good)
# 6                                       5 (Very Good)
# 7                                    3 (Satisfactory)
# 8                                            4 (Good)
# 9                                       5 (Very Good)
# 10                                      5 (Very Good)
# 11                                           4 (Good)
# 12                                      5 (Very Good)
# 13                                      5 (Very Good)
# 14                                      5 (Very Good)
# 15                                      5 (Very Good)
# ...

# %%
# third Competency in Subject data chunk

competency_to_match = "Competency in Subject"
chunk_competency = res_sheet.filter(like=competency_to_match)

# %%
chunk_competency
# Out:
#    Competency in Subject [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                  5 (Very Competent)
# 1                                  5 (Very Competent)
# 2                                  5 (Very Competent)
# 3                                  5 (Very Competent)
# 4                                  5 (Very Competent)
# 5                                  5 (Very Competent)
# 6                                  5 (Very Competent)
# 7                                       4 (Competent)
# 8                                       4 (Competent)
# 9                                  5 (Very Competent)
# 10                                 5 (Very Competent)
# 11                                      4 (Competent)
# 12                                 5 (Very Competent)
# 13                                 5 (Very Competent)
# 14                                 5 (Very Competent)
# 15                                 5 (Very Competent)
# ...

# %%
# fourth Usefulness of Topic/s data chunk

# %%
usefulness_to_match = ("Usefulness of Topic/s")
chunk_usefulness = res_sheet.filter(like=usefulness_to_match)

# %%
chunk_usefulness
# Out:
#    Usefulness of Topic/s [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]  \
# 0                                          4 (Useful)
# 1                                     5 (Very Useful)
# 2                                     5 (Very Useful)
# 3                                     5 (Very Useful)
# 4                                     5 (Very Useful)
# 5                                     5 (Very Useful)
# 6                                     5 (Very Useful)
# 7                                          4 (Useful)
# 8                                     5 (Very Useful)
# 9                                     5 (Very Useful)
# 10                                    5 (Very Useful)
# 11                                         4 (Useful)
# 12                                    5 (Very Useful)
# 13                                    5 (Very Useful)
# 14                                    5 (Very Useful)
# 15                                    5 (Very Useful)
# ...

# %%
# 13 other question data chunk

que_to_match = ("Did you find the course useful ?") 	#Resource Persons 	Duration	Broadening the approach	Inspiring	Skill Development   	Did you acquire sufficient skill in developing e-content using generic tools?	Did you acquire sufficient knowledge regarding your role and responsibilities in higher education?	Do you have the confidence in developing research proposal and writing research articles?  	Curriculum of the Course 	How would you rate the overall programme  	Suggest additional topics to be included if any	Any other aspect that needs improvement
chunk_to_que = res_sheet.filter(like=que_to_match)

# %%
# All Column Print in loop

for data in res_sheet:
    print(data)
# Out:
# Timestamp
# Email Address
# Select your Personal Details
# Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]
# Communication Skill [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]
# Communication Skill [Dr. Ragini Khubalkar (Intellectual Property Rights)]
# Communication Skill [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]
# Communication Skill [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]
# Communication Skill [Dr. Vivek Sharma (Teaching research in NEP 2020)]
# Communication Skill [Dr. N.K.Totla (Qualitative Research)]
# Communication Skill [Dr. Shine David (Exploratory Factor Analysis Using SPSS)]
# Communication Skill [Dr. Vivek Kushwah (Assesments using Rubrics in NEP 2020)]
# Communication Skill [Dr. Prateek Maheshwari (Inclusion of IKS into Indian Business and Management Education: reality and far away dream)]
# ...

# %%
#This data chunk qualitative to quantitative convert

#chunk_communication
#chunk_quality
#chunk_competency
#chunk_usefulness

# %%
#chunk_usefulness qualitative data replace and covert in quantitative data

a = chunk_communication.replace("5 (Very effective)",5)
b = a.replace("4 (Effective)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)

communication_qun_data = d
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\4062734362.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d = c.replace("2 (Ineffective)",2)

# %%
communication_qun_data

communication_rank = communication_qun_data.transpose()

#communication_rank

communication_sum = communication_rank.sum(axis=1)

#communication_sum

# %%
# chunk_quality qualitative data replace and convert in quantitative data

a = chunk_quality.replace("5 (Very Good)",5)
b = a.replace("4 (Good)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)



# all faculty data and response person row and column convertr
quality_rank = d.transpose()

quality_sum = quality_rank.sum(axis=1)

#quality_sum
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\1680817111.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   b = a.replace("4 (Good)",4)
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\1680817111.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   c = b.replace("3 (Satisfactory)",3)

# %%
# chunk_competency qualitative data replace and convert in quantitative data

a = chunk_competency.replace("5 (Very Competent)",5)
b = a.replace("4 (Competent)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)

# all faculty data and response person row and column convertr
competency_rank = d.transpose()

competency_sum = competency_rank.sum(axis=1)

#competency_sum
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\2369341399.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   b = a.replace("4 (Competent)",4)
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\2369341399.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   c = b.replace("3 (Satisfactory)",3)

# %%
# chunk_usefulness qualitative data replace and convert in quantitative data

a = chunk_usefulness.replace("5 (Very Useful)",5)
b = a.replace("4 (Useful)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Not Useful)",2)

# all faculty data and response person row and column convertr
usefulness_rank = d.transpose()

usefulness_sum = usefulness_rank.sum(axis=1)

#usefulness_sum
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\2120089229.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   b = a.replace("4 (Useful)",4)
# C:\Users\abc\AppData\Local\Temp\ipykernel_1968\2120089229.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   c = b.replace("3 (Satisfactory)",3)
# ...

# %%
type(communication_sum)
# Out:
# pandas.core.series.Series

# %%
# all file data sum in one variable

#communication_sum
#quality_sum
#competency_sum
#usefulness_sum




communication_list = communication_sum.values.tolist()
quality_list = quality_sum.values.tolist()
competency_list = competency_sum.values.tolist()
usefulness_list = usefulness_sum.values.tolist()

# %%
#DataFrame convert in all file

feedback_dataframe = pd.DataFrame({"Communication":communication_list,"Quality":quality_list,"Competency":competency_list,"Usefulness":usefulness_list})

feedback_dataframe


feedback_sum = feedback_dataframe.sum(axis=1)

feedback_sum

faculty_rating = feedback_sum/46/4

faculty_rat = pd.DataFrame({"faculty_rating":faculty_rating})


faculty = faculty_rat.values.tolist()

faculty


# Plot histogram
plt.hist(faculty, bins=10, color='blue', alpha=0.7)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Faculty Ratings')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 23
#      19 faculty
#      22 # Plot histogram
# ---> 23 plt.hist(faculty, bins=10, color='blue', alpha=0.7)
#      24 plt.xlabel('Rating')
#      25 plt.ylabel('Frequency')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3236, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3211 @_copy_docstring_and_deprecators(Axes.hist)
#    3212 def hist(
#    3213     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3234     BarContainer | Polygon | list[BarContainer | Polygon],
#    3235 ]:
# -> 3236     return gca().hist(
#    3237         x,
#    3238         bins=bins,
#    3239         range=range,
#    3240         density=density,
#    3241         weights=weights,
# ...
