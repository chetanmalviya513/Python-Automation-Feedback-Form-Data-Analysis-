# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import csv file
feedback_sheet = pd.read_csv(r"C:\Users\abc\Desktop\feedback\feedback.csv")

#print csv file
#feedback_sheet

# Total response count
total_response = len(feedback_sheet.index)

total_response
# Out:
# 46

# %% [markdown]
# Ques data
#
# 1. Communication Skill 2. Quality of lecture 3. Competency in Subject 4. Usefulness of Topic/s and other 13 Question chunk

# %%
# Communication skill chunk

communication_to_match = "Communication Skill"
chunk_communication = feedback_sheet.filter(like=communication_to_match)

#chunk_communication qualitative data convert quantitative data

a = chunk_communication.replace("5 (Very effective)",5)
b = a.replace("4 (Effective)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)
e = d.replace("1 (Netural)",1)

# store variable
communication_data = e

# row and column exchange - > (Transpose)
communication_res = communication_data.transpose()





communication_sum

#feedback_sheet
#chunk_communication
#communication_data
#communication_res
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\3906165309.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d = c.replace("2 (Ineffective)",2)
# Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]                                                                          214
# Communication Skill [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]                                                     215
# Communication Skill [Dr. Ragini Khubalkar (Intellectual Property Rights)]                                                                                      212
# Communication Skill [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]                                                      216
# Communication Skill [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]                                                               213
# Communication Skill [Dr. Vivek Sharma (Teaching research in NEP 2020)]                                                                                         210
# Communication Skill [Dr. N.K.Totla (Qualitative Research)]                                                                                                     214
# Communication Skill [Dr. Shine David (Exploratory Factor Analysis Using SPSS)]                                                                                 215
# Communication Skill [Dr. Vivek Kushwah (Assesments using Rubrics in NEP 2020)]                                                                                 213
# Communication Skill [Dr. Prateek Maheshwari (Inclusion of IKS into Indian Business and Management Education: reality and far away dream)]                      215
# Communication Skill [Dr Pradeep MishraOER )]                                                                                                                   216
# Communication Skill [Dr. Vasim Khan (5 Ds of Sustainable Development)]                                                                                         210
# Communication Skill [Prashant Kulkarni (Optimal Learning Environment and Mentoring Support to Students: Restructuring Vocational Education under NEP 2020)]    213
# Communication Skill [Prof Karunesh Saxena (Curriculum and Pedagogy in Higher Education )]                                                                      209
# Communication Skill [Prof Kapil Sharma (Implementing CBCS and Credit tranfer Mechanism in NEP 2020)]                                                           213
# Communication Skill [Prof. Jasim Ahmad (Flexibility in Choices of Subjets and Multiple Entry Exit System in Higher Education)]                                 210
# Communication Skill [Prof Alok bansal (Multiple regression analysis using SPSS)]                                                                               215
# Communication Skill [Prof PB Sharma (Making India a hub for Innovation and Solution Research)]                                                                 213
# Communication Skill [Dr. Anindita chatterjee (Work Life Balance : for Teachers)]                                                                               218
# Communication Skill [Dr Ashok sharma (Learning analytics)]                                                                                                     212
# Communication Skill [Prof Manish Sitlani (Regulatory framework in Higher education : NEP Highlights)]                                                          212
# Communication Skill [Prof. MOHIUDDIN SANGMI (Opportunities and challenges for commerce ,management  and economics Professionals in the light of NEP 2020)]     214
# Communication Skill [Vaibhav Neema (Latex)]                                                                                                                    210
# Communication Skill [Prof Alok bansal (Business Intelligence through Power BI)]                                                                                213
# Communication Skill [Prof Krishna awatar goyal (Financial technology- FINTECH)]                                                                                211
# Communication Skill [Prof. Umesh Holani (Work Life Balance through Indian Philosophy)]                                                                         209
# Communication Skill [Dr Sanjay Pandgale (Learning outcomes and scope of integrating technology)]                                                               210
# Communication Skill [Dr Sanjay Pandgale (Assistive Technology in Education)]                                                                                   212
# Communication Skill [Prof Satya Sundar Sethi ( Analysing the Importance of formative assessment for students)]                                                 212
# Communication Skill [Prof Satya Sundar Sethi ( Research Ethics and Publication practices in higher education setting)]                                         209
# Communication Skill [Dr. Anil Mehta (research paper  writing for Indexed Journals)]                                                                            215
# Communication Skill [Dr Yamini Karmarkar (Dr Yamini Karmarkar)]                                                                                                213
# Communication Skill [Dr. Deepak Bisla (Artificial Intelligence in education)]                                                                                  215
# Communication Skill [Prof Shefali Nagpal (Strategic Planning in Higher Education under NEP 2020)]                                                              213
# Communication Skill [Dr. Deepak Bisla (Developmennt of MOOCS under NEP)]                                                                                       219
# Communication Skill [Dr. V P Joshith (e-assessment under NEP-2020)]                                                                                            214
# dtype: int64

# %%
# all applicat rating of faculty data sum and assign in list
communication_sum = communication_res.sum(axis=1)

communication_sum
# Out:
# Communication Skill [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]                                                                          214
# Communication Skill [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]                                                     215
# Communication Skill [Dr. Ragini Khubalkar (Intellectual Property Rights)]                                                                                      212
# Communication Skill [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]                                                      216
# Communication Skill [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]                                                               213
# Communication Skill [Dr. Vivek Sharma (Teaching research in NEP 2020)]                                                                                         210
# Communication Skill [Dr. N.K.Totla (Qualitative Research)]                                                                                                     214
# Communication Skill [Dr. Shine David (Exploratory Factor Analysis Using SPSS)]                                                                                 215
# Communication Skill [Dr. Vivek Kushwah (Assesments using Rubrics in NEP 2020)]                                                                                 213
# Communication Skill [Dr. Prateek Maheshwari (Inclusion of IKS into Indian Business and Management Education: reality and far away dream)]                      215
# Communication Skill [Dr Pradeep MishraOER )]                                                                                                                   216
# Communication Skill [Dr. Vasim Khan (5 Ds of Sustainable Development)]                                                                                         210
# Communication Skill [Prashant Kulkarni (Optimal Learning Environment and Mentoring Support to Students: Restructuring Vocational Education under NEP 2020)]    213
# Communication Skill [Prof Karunesh Saxena (Curriculum and Pedagogy in Higher Education )]                                                                      209
# Communication Skill [Prof Kapil Sharma (Implementing CBCS and Credit tranfer Mechanism in NEP 2020)]                                                           213
# Communication Skill [Prof. Jasim Ahmad (Flexibility in Choices of Subjets and Multiple Entry Exit System in Higher Education)]                                 210
# Communication Skill [Prof Alok bansal (Multiple regression analysis using SPSS)]                                                                               215
# Communication Skill [Prof PB Sharma (Making India a hub for Innovation and Solution Research)]                                                                 213
# Communication Skill [Dr. Anindita chatterjee (Work Life Balance : for Teachers)]                                                                               218
# Communication Skill [Dr Ashok sharma (Learning analytics)]                                                                                                     212
# Communication Skill [Prof Manish Sitlani (Regulatory framework in Higher education : NEP Highlights)]                                                          212
# Communication Skill [Alok Chakrawal (Implementa...   5   3   5
# Communication Skill [Dr. Sandeep Atre (Teacher ...   5   2   5
# Communication Skill [Dr. Ragini Khubalkar (Inte...   5   2   5
# Communication Skill [Dr. Vaniki Joshi (Developi...   5   2   5
# Communication Skill [Dr. Mohit Lohane (Digital ...   5   3   5
# Communication Skill [Dr. Vivek Sharma (Teaching...   5   3   5
# Communication Skill [Dr. N.K.Totla (Qualitative...   5   2   5
# Communication Skill [Dr. Shine David (Explorato...   5   3   5
# Communication Skill [Dr. Vivek Kushwah (Assesme...   5   3   5
# Communication Skill [Dr. Prateek Maheshwari (In...   5   3   5
# Communication Skill [Dr Pradeep MishraOER )]         5   4   5
# Communication Skill [Dr. Vasim Khan (5 Ds of Su...   5   3   5
# Communication Skill [Prashant Kulkarni (Optimal...   5   4   5
# Communication Skill [Prof Karunesh Saxena (Curr...   5   4   5
# Communication Skill [Prof Kapil Sharma (Impleme...   5   5   5
# Communication Skill [Prof. Jasim Ahmad (Flexibi...   5   4   5
# Communication Skill [Prof Alok bansal (Multiple...   5   5   5
# Communication Skill [Prof PB Sharma (Making Ind...   5   4   5
# Communication Skill [Dr. Anindita chatterjee (W...   5   5   5
# Communication Skill [Dr Ashok sharma (Learning ...   5   4   5
# Communication Skill [Prof Manish Sitlani (Regul...   5   4   5
# Communication Skill [Prof. MOHIUDDIN SANGMI (Op...   5   5   5
# Communication Skill [Vaibhav Neema (Latex)]          5   4   5
# Communication Skill [Prof Alok bansal (Business...   5   5   5
# Communication Skill [Prof Krishna awatar goyal ...   5   4   5
# Communication Skill [Prof. Umesh Holani (Work L...   5   5   5
# Communication Skill [Dr Sanjay Pandgale (Learni...   5   5   5
# Communication Skill [Dr Sanjay Pandgale (Assist...   5   4   5
# Communication Skill [Prof Satya Sundar Sethi ( ...   5   5   5
# Communication Skill [Prof Satya Sundar Sethi ( ...   5   4   5
# Communication Skill [Dr. Anil Mehta (research p...   5   5   5
# Communication Skill [Dr Yamini Karmarkar (Dr Ya...   5   5   5
# Communication Skill [Dr. Deepak Bisla (Artifici...   5   4   5
# Communication Skill [Prof Shefali Nagpal (Strat...   5   5   5
# Communication Skill [Dr. Deepak Bisla (Developm...   5   5   5
# Communication Skill [Dr. V P Joshith (e-assessm...   5   4   5
#
# [36 rows x 46 columns]

# %%
# Quality of lecture

quality_to_match = "Quality of lecture"
chunk_quality = feedback_sheet.filter(like=quality_to_match)

#chunk_communication qualitative data convert quantitative data

a = chunk_quality.replace("5 (Very Good)",5)
b = a.replace("4 (Good)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)
e = d.replace("1 (Netural)",1)

# store variable
quality_clean_data = e

# row and column exchange - > (Transpose)
quality_transpose = quality_clean_data.transpose()

quality_sum = quality_transpose.sum(axis=1)

quality_sum
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\1272696186.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   b = a.replace("4 (Good)",4)
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\1272696186.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   c = b.replace("3 (Satisfactory)",3)
# Quality of lecture [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]                                                                          219
# Quality of lecture [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]                                                     220
# Quality of lecture [Dr. Ragini Khubalkar (Intellectual Property Rights)]                                                                                      216
# Quality of lecture [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]                                                      217
# Quality of lecture [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]                                                               216
# Quality of lecture [Dr. Vivek Sharma (Teaching research in NEP 2020)]                                                                                         217
# Quality of lecture [Dr. N.K.Totla (Qualitative Research)]                                                                                                     214
# Quality of lecture [Dr. Shine David (Exploratory Factor Analysis Using SPSS)]                                                                                 217
# Quality of lecture [Dr. Vivek Kushwah (Assesments using Rubrics in NEP 2020)]                                                                                 216
# Quality of lecture [Dr. Prateek Maheshwari (Inclusion of IKS into Indian Business and Management Education: reality and far away dream)]                      218
# Quality of lecture [Dr Pradeep MishraOER)]                                                                                                                    216
# Quality of lecture [Dr. Vasim Khan (5 Ds of Sustainable Development)]                                                                                         217
# Quality of lecture [Prashant Kulkarni (Optimal Learning Environment and Mentoring Support to Students: Restructuring Vocational Education under NEP 2020)]    220
# Quality of lecture [Prof Karunesh Saxena (Curriculum and Pedagogy in Higher Education )]                                                                      214
# Quality of lecture [Prof Kapil Sharma (Implementing CBCS and Credit tranfer Mechanism in NEP 2020)]                                                           217
# Quality of lecture [Prof. Jasim Ahmad (Flexibility in Choices of Subjets and Multiple Entry Exit System in Higher Education)]                                 215
# Quality of lecture [Prof Alok bansal (Multiple regression analysis using SPSS)]                                                                               215
# Quality of lecture [Prof PB Sharma (Making India a hub for Innovation and Solution Research)]                                                                 215
# Quality of lecture [Dr. Anindita chatterjee (Work Life Balance : for Teachers)]                                                                               220
# Quality of lecture [Dr Ashok sharma (Learning analytics)]                                                                                                     218
# Quality of lecture [Prof Manish Sitlani (Regulatory framework in Higher education : NEP Highlights)]                                                          218
# Quality of lecture [Prof. MOHIUDDIN SANGMI (Opportunities and challenges for commerce ,management  and economics Professionals in the light of NEP 2020)]     215
# Quality of lecture [Vaibhav Neema (Latex)]                                                                                                                    216
# Quality of lecture [Prof Alok bansal (Business Intelligence through Power BI)]                                                                                218
# Quality of lecture [Prof Krishna awatar goyal (Financial technology- FINTECH)]                                                                                218
# Quality of lecture [Prof. Umesh Holani (Work Life Balance through Indian Philosophy)]                                                                         217
# Quality of lecture [Dr Sanjay Pandgale (Learning outcomes and scope of integrating technology)]                                                               218
# Quality of lecture [Dr Sanjay Pandgale (Assistive Technology in Education)]                                                                                   216
# Quality of lecture [Prof Satya Sundar Sethi ( Analysing the Importance of formative assessment for students)]                                                 216
# Quality of lecture [Prof Satya Sundar Sethi ( Research Ethics and Publication practices in higher education setting)]                                         217
# Quality of lecture [Dr. Anil Mehta (research paper  writing for Indexed Journals)]                                                                            219
# Quality of lecture [Dr Yamini Karmarkar (Dr Yamini Karmarkar)]                                                                                                217
# Quality of lecture [Dr. Deepak Bisla (Artificial Intelligence in education)]                                                                                  217
# Quality of lecture [Prof Shefali Nagpal (Strategic Planning in Higher Education under NEP 2020)]                                                              214
# Quality of lecture [Dr. Deepak Bisla (Developmennt of MOOCS under NEP)]                                                                                       219
# Quality of lecture [Dr. V P Joshith (e-assessment under NEP-2020)]                                                                                            219
# dtype: int64

# %%
# Competency in Subject

competency_to_match = "Competency in Subject"
chunk_compentency = feedback_sheet.filter(like=competency_to_match)

#chunk_compentency qualitative data convert quantitative data


#chunk_compentency

a = chunk_compentency.replace("5 (Very Competent)",5)
b = a.replace("4 (Competent)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Ineffective)",2)
e = d.replace("1 (Netural)",1)



# store variable
compentency_clean_data = e

# row and column exchange - > (Transpose)
compentency_transpose = compentency_clean_data.transpose()

compentency_sum = compentency_transpose.sum(axis=1)

compentency_sum
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\3284093656.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   b = a.replace("4 (Competent)",4)
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\3284093656.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   c = b.replace("3 (Satisfactory)",3)
# Competency in Subject [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]                                                                          219
# Competency in Subject [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]                                                     218
# Competency in Subject [Dr. Ragini Khubalkar (Intellectual Property Rights)]                                                                                      218
# Competency in Subject [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]                                                      222
# Competency in Subject [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]                                                               220
# Competency in Subject [Dr. Vivek Sharma (Teaching research in NEP 2020)]                                                                                         216
# Competency in Subject [Dr. N.K.Totla (Qualitative Research)]                                                                                                     219
# Competency in Subject [Dr. Shine David (Exploratory Factor Analysis Using SPSS)]                                                                                 215
# Competency in Subject [Dr. Vivek Kushwah (Assesments using Rubrics in NEP 2020)]                                                                                 218
# Competency in Subject [Dr. Prateek Maheshwari (Inclusion of IKS into Indian Business and Management Education: reality and far away dream)]                      220
# Competency in Subject [Dr Pradeep MishraOER)]                                                                                                                    219
# Competency in Subject [Dr. Vasim Khan (5 Ds of Sustainable Development)]                                                                                         216
# Competency in Subject [Prashant Kulkarni (Optimal Learning Environment and Mentoring Support to Students: Restructuring Vocational Education under NEP 2020)]    221
# Competency in Subject [Prof Karunesh Saxena (Curriculum and Pedagogy in Higher Education )]                                                                      218
# Competency in Subject [Prof Kapil Sharma (Implementing CBCS and Credit tranfer Mechanism in NEP 2020)]                                                           219
# Competency in Subject [Prof. Jasim Ahmad (Flexibility in Choices of Subjets and Multiple Entry Exit System in Higher Education)]                                 217
# Competency in Subject [Prof Alok bansal (Multiple regression analysis using SPSS)]                                                                               218
# Competency in Subject [Prof PB Sharma (Making India a hub for Innovation and Solution Research)]                                                                 220
# Competency in Subject [Dr. Anindita chatterjee (Work Life Balance : for Teachers)]                                                                               223
# Competency in Subject [Dr Ashok sharma (Learning analytics)]                                                                                                     219
# Competency in Subject [Prof Manish Sitlani (Regulatory framework in Higher education : NEP Highlights)]                                                          220
# Competency in Subject [Prof. MOHIUDDIN SANGMI (Opportunities and challenges for commerce ,management  and economics Professionals in the light of NEP 2020)]     219
# Competency in Subject [Vaibhav Neema (Latex)]                                                                                                                    219
# Competency in Subject [Prof Alok bansal (Business Intelligence through Power BI)]                                                                                216
# Competency in Subject [Prof Krishna awatar goyal (Financial technology- FINTECH)]                                                                                219
# Competency in Subject [Prof. Umesh Holani (Work Life Balance through Indian Philosophy)]                                                                         216
# Competency in Subject [Dr Sanjay Pandgale (Learning outcomes and scope of integrating technology)]                                                               217
# Competency in Subject [Dr Sanjay Pandgale (Assistive Technology in Education)]                                                                                   218
# Competency in Subject [Prof Satya Sundar Sethi ( Analysing the Importance of formative assessment for students)]                                                 220
# Competency in Subject [Prof Satya Sundar Sethi ( Research Ethics and Publication practices in higher education setting)]                                         221
# Competency in Subject [Dr. Anil Mehta (research paper  writing for Indexed Journals)]                                                                            220
# Competency in Subject [Dr Yamini Karmarkar (Dr Yamini Karmarkar)]                                                                                                220
# Competency in Subject [Dr. Deepak Bisla (Artificial Intelligence in education)]                                                                                  220
# Competency in Subject [Prof Shefali Nagpal (Strategic Planning in Higher Education under NEP 2020)]                                                              219
# Competency in Subject [Dr. Deepak Bisla (Developmennt of MOOCS under NEP)]                                                                                       221
# Competency in Subject [Dr. V P Joshith (e-assessment under NEP-2020)]                                                                                            220
# dtype: int64

# %%
# Usefulness of Topic/s

usefulness_to_match = "Usefulness of Topic/s"
chunk_usefulness = feedback_sheet.filter(like=usefulness_to_match)

#chunk_Usefulness of Topic/s qualitative data convert quantitative data


a = chunk_usefulness.replace("5 (Very Useful)",5)
b = a.replace("4 (Useful)",4)
c = b.replace("3 (Satisfactory)",3)
d = c.replace("2 (Not Useful)",2)
e = d.replace("1 (Netural)",1)



# store variable
usefulness_clean_data = e

# row and column exchange - > (Transpose)
usefulness_transpose = usefulness_clean_data.transpose()

usefulness_sum = usefulness_transpose.sum(axis=1)

type(usefulness_sum)

usefulness_sum
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\2177906692.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   b = a.replace("4 (Useful)",4)
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\2177906692.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   c = b.replace("3 (Satisfactory)",3)
# C:\Users\abc\AppData\Local\Temp\ipykernel_5908\2177906692.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d = c.replace("2 (Not Useful)",2)
# Usefulness of Topic/s [Alok Chakrawal (Implementation of NEP 2020 in Higher Education)]                                                                          221
# Usefulness of Topic/s [Dr. Sandeep Atre (Teacher as an enabler of holistic and Multidisciplinary education)]                                                     222
# Usefulness of Topic/s [Dr. Ragini Khubalkar (Intellectual Property Rights)]                                                                                      217
# Usefulness of Topic/s [Dr. Vaniki Joshi (Developing area in finance and enterpreneurship: A roadmap Ahead)]                                                      220
# Usefulness of Topic/s [Dr. Mohit Lohane (Digital Road Map to Academic & Institutional Excellence)]                                                               224
# Usefulness of Topic/s [Dr. Vivek Sharma (Teaching research in NEP 2020)]                                                                                         220
# Usefulness of Topic/s [Dr. N.K.Totla (Qualitative Research)]                                                                                                     219
# Usefulness of Topic/s [Dr. Shine David (Exploratory Factor Analysis Using SPSS)]                                                                                 222
# Usefulness of Topic/s [Dr. Vivek Kushwah (Assesments using Rubrics in NEP 2020)]                                                                                 221
# Usefulness of Topic/s [Dr. Prateek Maheshwari (Inclusion of IKS into Indian Business and Management Education: reality and far away dream)]                      222
# Usefulness of Topic/s [Dr Pradeep MishraOER)]                                                                                                                    220
# Usefulness of Topic/s [Dr. Vasim Khan (5 Ds of Sustainable Development)]                                                                                         223
# Usefulness of Topic/s [Prashant Kulkarni (Optimal Learning Environment and Mentoring Support to Students: Restructuring Vocational Education under NEP 2020)]    222
# Usefulness of Topic/s [Prof Karunesh Saxena (Curriculum and Pedagogy in Higher Education )]                                                                      223
# Usefulness of Topic/s [Prof Kapil Sharma (Implementing CBCS and Credit tranfer Mechanism in NEP 2020)]                                                           224
# Usefulness of Topic/s [Prof. Jasim Ahmad (Flexibility in Choices of Subjets and Multiple Entry Exit System in Higher Education)]                                 222
# Usefulness of Topic/s [Prof Alok bansal (Multiple regression analysis using SPSS)]                                                                               223
# Usefulness of Topic/s [Prof PB Sharma (Making India a hub for Innovation and Solution Research)]                                                                 223
# Usefulness of Topic/s [Dr. Anindita chatterjee (Work Life Balance : for Teachers)]                                                                               223
# Usefulness of Topic/s [Dr Ashok sharma (Learning analytics)]                                                                                                     223
# Usefulness of Topic/s [Prof Manish Sitlani (Regulatory framework in Higher education : NEP Highlights)]                                                          223
# Usefulness of Topic/s [Prof. MOHIUDDIN SANGMI (Opportunities and challenges for commerce ,management  and economics Professionals in the light of NEP 2020)]     224
# Usefulness of Topic/s [Vaibhav Neema (Latex)]                                                                                                                    218
# Usefulness of Topic/s [Prof Alok bansal (Business Intelligence through Power BI)]                                                                                224
# Usefulness of Topic/s [Prof Krishna awatar goyal (Financial technology- FINTECH)]                                                                                223
# Usefulness of Topic/s [Prof. Umesh Holani (Work Life Balance through Indian Philosophy)]                                                                         222
# Usefulness of Topic/s [Dr Sanjay Pandgale (Learning outcomes and scope of integrating technology)]                                                               221
# Usefulness of Topic/s [Dr Sanjay Pandgale (Assistive Technology in Education)]                                                                                   221
# Usefulness of Topic/s [Prof Satya Sundar Sethi ( Analysing the Importance of formative assessment for students)]                                                 222
# Usefulness of Topic/s [Prof Satya Sundar Sethi ( Research Ethics and Publication practices in higher education setting)]                                         225
# Usefulness of Topic/s [Dr. Anil Mehta (research paper  writing for Indexed Journals)]                                                                            223
# Usefulness of Topic/s [Dr Yamini Karmarkar (Dr Yamini Karmarkar)]                                                                                                222
# Usefulness of Topic/s [Dr. Deepak Bisla (Artificial Intelligence in education)]                                                                                  224
# Usefulness of Topic/s [Prof Shefali Nagpal (Strategic Planning in Higher Education under NEP 2020)]                                                              220
# Usefulness of Topic/s [Dr. Deepak Bisla (Developmennt of MOOCS under NEP)]                                                                                       222
# Usefulness of Topic/s [Dr. V P Joshith (e-assessment under NEP-2020)]                                                                                            224
# dtype: int64

# %%
#feedback_sheet

type(usefulness_sum)
chunk_compentency
chunk_communication

mylist = []
for i in chunk_communication:
    mylist.append(i)

df = pd.Series(mylist)

faculty_data = pd.DataFrame({"Faculty_text":df})

faculty_data.head()

# #faculty.Faculty_text.str.extract(r'\[(.*?)\(')
faculty = faculty_data.Faculty_text.str.extract(r"\[(.*?)\(")  

faculty_name = []
for i in faculty[0]:
    faculty_name.append(i)

faculty_name[10] = "Dr Pradeep MishraOER"

# %%
# faculty average rating data list assign uses for dataframe create

communication_list = communication_sum.values.tolist()
quality_list = quality_sum.values.tolist()
competency_list = compentency_sum.values.tolist()
usefulness_list = usefulness_sum.values.tolist()
#faculty_name




#DataFrame convert in 4 column  1.Communication	2.Quality	3.Competency	4.Usefulness 

feedback_dataframe = pd.DataFrame(
    {"faculty_name":faculty_name,"Communication":communication_list,
     "Quality":quality_list,"Competency":competency_list,"Usefulness":usefulness_list})

#feedback_dataframe

# %%
# total sum in 1.Communication	2.Quality	3.Competency	4.Usefulness  column 
feedback_total_all = feedback_dataframe.set_index("faculty_name")[['Communication', 'Quality', 'Competency', 'Usefulness']].sum(axis=1)


# calculate average rating  
feedback = feedback_dataframe.set_index("faculty_name")[['Communication', 'Quality', 'Competency', 'Usefulness']].sum(axis=1)/total_response/4
feedback = round(feedback, 2)

# %%
# feedback_total_all and feedback average rating and faculy name all column show and excel file export
 
total_all = []
for i in feedback_total_all:
    total_all.append(i)
#print(total_all)

# average rating variable store
feedback_rating = feedback

#feedback_rating

total_rating = []
for i in feedback_rating:
    total_rating.append(i)
#print(total_rating)

fac_tot_rat = total_rating

total_score = pd.DataFrame({"feedback_total":total_all,"total_rating":total_rating})


#feedback_dataframe
#total_score

#total_rating

feedback_final_score = pd.concat([feedback_dataframe, total_score], axis=1)

#Feedback final excel file export
#feedback_final_score.to_excel("feedback_final_score.xlsx")



feedback_final_score
# Out:
#                   faculty_name  Communication  Quality  Competency  \
# 0              Alok Chakrawal             214      219         219
# 1            Dr. Sandeep Atre             215      220         218
# 2        Dr. Ragini Khubalkar             212      216         218
# 3            Dr. Vaniki Joshi             216      217         222
# 4            Dr. Mohit Lohane             213      216         220
# 5            Dr. Vivek Sharma             210      217         216
# 6               Dr. N.K.Totla             214      214         219
# 7             Dr. Shine David             215      217         215
# 8           Dr. Vivek Kushwah             213      216         218
# 9      Dr. Prateek Maheshwari             215      218         220
# 10        Dr Pradeep MishraOER            216      216         219
# 11             Dr. Vasim Khan             210      217         216
# 12          Prashant Kulkarni             213      220         221
# 13       Prof Karunesh Saxena             209      214         218
# 14          Prof Kapil Sharma             213      217         219
# 15          Prof. Jasim Ahmad             210      215         217
# 16           Prof Alok bansal             215      215         218
# 17             Prof PB Sharma             213      215         220
# 18    Dr. Anindita chatterjee             218      220         223
# 19            Dr Ashok sharma             212      218         219
# 20        Prof Manish Sitlani             212      218         220
# 21     Prof. MOHIUDDIN SANGMI             214      215         219
# 22              Vaibhav Neema             210      216         219
# 23           Prof Alok bansal             213      218         216
# 24  Prof Krishna awatar goyal             211      218         219
# 25         Prof. Umesh Holani             209      217         216
# 26         Dr Sanjay Pandgale             210      218         217
# 27         Dr Sanjay Pandgale             212      216         218
# 28    Prof Satya Sundar Sethi             212      216         220
# 29    Prof Satya Sundar Sethi             209      217         221
# 30             Dr. Anil Mehta             215      219         220
# 31        Dr Yamini Karmarkar             213      217         220
# 32           Dr. Deepak Bisla             215      217         220
# 33        Prof Shefali Nagpal             213      214         219
# 34           Dr. Deepak Bisla             219      219         221
# 35            Dr. V P Joshith             214      219         220
#
#     Usefulness  feedback_total  total_rating
# 0          221             873          4.74
# 1          222             875          4.76
# 2          217             863          4.69
# 3          220             875          4.76
# 4          224             873          4.74
# 5          220             863          4.69
# 6          219             866          4.71
# 7          222             869          4.72
# 8          221             868          4.72
# 9          222             875          4.76
# 10         220             871          4.73
# 11         223             866          4.71
# 12         222             876          4.76
# 13         223             864          4.70
# 14         224             873          4.74
# 15         222             864          4.70
# 16         223             871          4.73
# 17         223             871          4.73
# 18         223             884          4.80
# 19         223             872          4.74
# 20         223             873          4.74
# 21         224             872          4.74
# 22         218             863          4.69
# 23         224             871          4.73
# 24         223             871          4.73
# 25         222             864          4.70
# 26         221             866          4.71
# 27         221             867          4.71
# 28         222             870          4.73
# 29         225             872          4.74
# 30         223             877          4.77
# 31         222             872          4.74
# 32         224             876          4.76
# 33         220             866          4.71
# 34         222             881          4.79
# 35         224             877          4.77

# %%
feedback_final_score
# Out:
#                   faculty_name  Communication  Quality  Competency  \
# 0              Alok Chakrawal             214      219         219
# 1            Dr. Sandeep Atre             215      220         218
# 2        Dr. Ragini Khubalkar             212      216         218
# 3            Dr. Vaniki Joshi             216      217         222
# 4            Dr. Mohit Lohane             213      216         220
# 5            Dr. Vivek Sharma             210      217         216
# 6               Dr. N.K.Totla             214      214         219
# 7             Dr. Shine David             215      217         215
# 8           Dr. Vivek Kushwah             213      216         218
# 9      Dr. Prateek Maheshwari             215      218         220
# 10        Dr Pradeep MishraOER            216      216         219
# 11             Dr. Vasim Khan             210      217         216
# 12          Prashant Kulkarni             213      220         221
# 13       Prof Karunesh Saxena             209      214         218
# 14          Prof Kapil Sharma             213      217         219
# 15          Prof. Jasim Ahmad             210      215         217
# 16           Prof Alok bansal             215      215         218
# 17             Prof PB Sharma             213      215         220
# 18    Dr. Anindita chatterjee             218      220         223
# 19            Dr Ashok sharma             212      218         219
# 20        Prof Manish Sitlani             212      218         220
# 21     Prof. MOHIUDDIN SANGMI             214      215         219
# 22              Vaibhav Neema             210      216         219
# 23           Prof Alok bansal             213      218         216
# 24  Prof Krishna awatar goyal             211      218         219
# 25         Prof. Umesh Holani             209      217         216
# 26         Dr Sanjay Pandgale             210      218         217
# 27         Dr Sanjay Pandgale             212      216         218
# 28    Prof Satya Sundar Sethi             212      216         220
# 29    Prof Satya Sundar Sethi             209      217         221
# 30             Dr. Anil Mehta             215      219         220
# 31        Dr Yamini Karmarkar             213      217         220
# 32           Dr. Deepak Bisla             215      217         220
# 33        Prof Shefali Nagpal             213      214         219
# 34           Dr. Deepak Bisla             219      219         221
# 35            Dr. V P Joshith             214      219         220
#
#     Usefulness  feedback_total  total_rating
# 0          221             873          4.74
# 1          222             875          4.76
# 2          217             863          4.69
# 3          220             875          4.76
# 4          224             873          4.74
# 5          220             863          4.69
# 6          219             866          4.71
# 7          222             869          4.72
# 8          221             868          4.72
# 9          222             875          4.76
# 10         220             871          4.73
# 11         223             866          4.71
# 12         222             876          4.76
# 13         223             864          4.70
# 14         224             873          4.74
# 15         222             864          4.70
# 16         223             871          4.73
# 17         223             871          4.73
# 18         223             884          4.80
# 19         223             872          4.74
# 20         223             873          4.74
# 21         224             872          4.74
# 22         218             863          4.69
# 23         224             871          4.73
# 24         223             871          4.73
# 25         222             864          4.70
# 26         221             866          4.71
# 27         221             867          4.71
# 28         222             870          4.73
# 29         225             872          4.74
# 30         223             877          4.77
# 31         222             872          4.74
# 32         224             876          4.76
# 33         220             866          4.71
# 34         222             881          4.79
# 35         224             877          4.77

# %%
# Faculty Rating final bar graph show


plt.figure(figsize=(15, 8))
bars = feedback.plot(kind='bar')
plt.title('Average Ratings by Faculty')
plt.xlabel('Faculty')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.yticks([1, 2, 3, 4.0, 4.1, 4.2, 4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 4.9, 5.0])

# Set the lower limit of the y-axis to 4
plt.ylim(4, 5)

# Adding data labels
for bar in bars.patches:
    plt.annotate(format(bar.get_height(), '.2f'), 
                 (bar.get_x() + bar.get_width() / 2, 
                  bar.get_height()), 
                 ha='center', va='center',
                 xytext=(0, 5), 
                 textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
import numpy as np

# Prepare data for 3D bar graph
categories = faculty_name
values = fac_tot_rat

fig = plt.figure(figsize=(19, 35))
#fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(111, projection='3d')

# Position of bars on x-axis
xpos = np.arange(len(categories))
ypos = np.zeros(len(categories))  # y positions are all zero for a 2D bar graph
zpos = np.zeros(len(categories))

# The width and depth of the bars
dx = np.ones(len(categories)) * 0.6  # Width of the bars
dy = np.ones(len(categories))  # Depth of the bars
dz = values

# Plot bars
ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='blue', edgecolor='black')

# Labeling the x-axis
ax.set_xticks(xpos)
ax.set_xticklabels(categories)

# Labeling axes
#ax.set_xlabel('Category')
#ax.set_ylabel('Y')
ax.set_zlabel('Percentage')


# Rotate x-axis labels
for label in ax.get_xticklabels():
    label.set_rotation(90)



#Title set
#ax.set_title("12. How would you rate the overall programme ", fontsize= 15)

#ax.set_zlim([4, 5])

# Remove y-ticks
ax.set_yticks([])
#ax.set_zticks([4.0, 4.2, 4.4, 4.6, 4.8, 4.10])




ax.set 
# Set the viewing angle to 89 degrees
ax.view_init(elev=1., azim=89)

# Add value labels on top of bars
for i in range(len(categories)):
    ax.text(xpos[i], ypos[i], dz[i], f'{dz[i]}%', ha='right', va='bottom', fontsize=11, )

# Set figure width
#fig.set_figwidth(25)
#plt.figure().set_figwidth(25)
#plt.figure().set_figheight(40)


# Show the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
categories = faculty_name
values = fac_tot_rat

fig = plt.figure(figsize=(20, 30))
ax = fig.add_subplot(111, projection='3d')

xpos = np.arange(len(categories))
ypos = np.zeros(len(categories))
zpos = np.zeros(len(categories))
dx = np.ones(len(categories)) * 0.1
dy = np.ones(len(categories))* 0.1
dz = values

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='blue', edgecolor='black')

ax.set_xticks(xpos)
ax.set_xticklabels(categories, rotation=90)

ax.set_zlabel('Percentage')

for label in ax.get_xticklabels():
    label.set_rotation(90)

#ax.set_zlim(5, 6)  # Set z-axis limits from 4 to 5

ax.set_yticks([])
ax.set_zticks(np.linspace(2, max(dz), 1)) # Adjust z-axis ticks accordingly


ax.view_init(elev=1., azim=89)

for i in range(len(categories)):
    ax.text(xpos[i], ypos[i], dz[i], f'{dz[i]}%', ha='right', va='bottom', fontsize=11)

plt.show()

# %%
# Faculty Rating final bar graph show

plt.figure(figsize=(15, 8))
bars = feedback.plot(kind='bar')
plt.title('Average Ratings by Faculty')
plt.xlabel('Faculty')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.yticks([1, 2, 3, 4.0, 4.1, 4.2, 4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 4.9, 5.0])

# Set the lower limit of the y-axis to 4
plt.ylim(4, 5)

plt.tight_layout()
plt.show()
